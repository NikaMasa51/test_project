# %% [markdown]
# # 雑草の生育期間を区別して分類器を作る（芽生え）

# %% [markdown]
# ■グーグルドライブをマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ■clusterディレクトリをカレントにコピー
# ※driveのデータを直接変更しないようにあらかじめコピーしておく

# %%
# %cp -r ./drive/My\ Drive/cluster ./

# %% [markdown]
# ■ディレクトリを作成

# %%
import os, shutil

# The directory where we will
# store our smaller dataset
base_dir = "./CLS"
if "CLS" not in os.listdir("./"):
  os.mkdir(base_dir)
else:
  print(base_dir, "は既に存在します")

train_index = "train"
train_dir = os.path.join(base_dir, train_index)
if train_index not in os.listdir(base_dir):
  os.mkdir(train_dir)
else:
  print(train_dir + "は既に存在します")

validation_index = "validation"
validation_dir = os.path.join(base_dir, validation_index)
if validation_index not in os.listdir(base_dir):
  os.mkdir(validation_dir)
else:
  print(validation_dir + "は既に存在します")

prediction_index = "prediction"
prediction_dir = os.path.join(base_dir, prediction_index)
if prediction_index not in os.listdir(base_dir):
  os.mkdir(prediction_dir)
else:
  print(prediction_dir + "は既に存在します")

#10分類のclassを入力
classes=["hakidamegiku","hosoaogeitou","ichibi",
         "inubie","kosendangusa","mameasagao",
         "mehishiba","ohishiba","oinutade","shiroza",]
dirs = os.listdir(base_dir)
for dir in dirs:
  for cls in classes:
    # Directory with our training pictures
    class_dir = os.path.join(base_dir, dir, cls)
    if cls not in os.listdir(base_dir + "/" + dir):
      os.mkdir(class_dir)
    else:
      print(class_dir, "は既に存在します")

# %% [markdown]
# ■ディレクトリに画像をランダムに振り分け

# %%
from os.path import join
import random

clsdir = "./cluster"
base_dir = "./CLS"
dirs = os.listdir(base_dir)
# weed_typeを芽生えのみに設定
weed_types = ["sprout"]
weed_names = os.listdir(clsdir)
# ファイル（クラスごとに分かれている）を順番に読み取り
# train, validationデータを作成
for weed_name in weed_names:
  for weed_type in weed_types: 
    print(weed_name, "/",weed_type)
    file_names = os.listdir(os.path.join(clsdir, weed_name, weed_type))
    files100 = random.sample(file_names, int(100))
    num1 = 0
    num2 = 0
    for file_name in file_names:
      if  file_name in files100:
        if num1 >= 90:
          continue
        # 移動元のファイル
        path1 = os.path.join(clsdir, weed_name, weed_type, file_name)
        # 移動先のファイル
        path2= os.path.join(base_dir, "train", weed_name, file_name)
        # ファイルを移動
        new_path = shutil.move(path1, path2)
        # ファイルの存在確認
        print(os.path.exists(path2))
        num1 = num1 + 1
      else:
        if num2 >= 90:
          continue 
        # 移動元のファイル
        path1 = os.path.join(clsdir, weed_name, weed_type, file_name)
        # 移動先のファイル
        path2= os.path.join(base_dir, "validation", weed_name, file_name)
        # ファイルを移動
        new_path = shutil.move(path1, path2)
        # ファイルの存在確認
        print(os.path.exists(path2))
        num2 = num2 + 1

# predictionデータを作成
for weed_name in weed_names:
  for weed_type in weed_types:
    print(weed_name, "/",weed_type)
    file_names = os.listdir(os.path.join(clsdir, weed_name, weed_type))
    for file_name in file_names:      
      # 移動元のファイル
      path1 = os.path.join(clsdir, weed_name, weed_type, file_name)
      # 移動先のファイル
      path2= os.path.join(base_dir, "prediction", weed_name, file_name)
      # ファイルを移動
      new_path = shutil.move(path1, path2)
      # ファイルの存在確認
      print(os.path.exists(path2))
# Out:
# kosendangusa / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# inubie / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ohishiba / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# hakidamegiku / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# hosoaogeitou / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# oinutade / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# shiroza / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# mameasagao / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ichibi / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# mehishiba / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# kosendangusa / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# inubie / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ohishiba / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# hakidamegiku / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# hosoaogeitou / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# oinutade / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# shiroza / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# mameasagao / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ichibi / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# mehishiba / sprout
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ■解凍したファイルをそれぞれ訓練データと検証用のデータに分けます

# %%
import os 
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import keras.preprocessing.image as Image

input_size = 224

train_dir = "./CLS/train"
validation_dir = "./CLS/validation"
prediction_dir = "./CLS/prediction"


train_datagen = Image.ImageDataGenerator(
            featurewise_center = False,
            samplewise_center = False,
            featurewise_std_normalization = False,
            samplewise_std_normalization = False,
            zca_whitening = False,
            rotation_range = 90,
            width_shift_range = 0.3,
            height_shift_range = 0.3,
            horizontal_flip = True,
            vertical_flip = False,
            rescale=1./255
        )

val_datagen = Image.ImageDataGenerator(rescale=1./255)



train_generator = train_datagen.flow_from_directory(
            train_dir,
            target_size=(input_size,input_size),
            batch_size=10,
            class_mode='categorical'
        )

validation_generator = val_datagen.flow_from_directory(
            validation_dir,
            target_size=(input_size,input_size),
            batch_size=10,
            class_mode='categorical'
        )


prediction_generator = val_datagen.flow_from_directory(
            prediction_dir,
            target_size=(input_size,input_size),
            batch_size=10,
            class_mode='categorical'
        )
# Out:
# Using TensorFlow backend.
# Found 900 images belonging to 10 classes.
# Found 900 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %% [markdown]
# ■学習開始

# %%
#ファインチューニング+VGG+水増し。ここから実行してOK（VGG16をダウンロード）
from keras import models
from keras import layers
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.applications import VGG16
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import History, Callback
from keras.objectives import categorical_crossentropy
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score
from keras.utils import to_categorical
from scipy.stats import mode
import os, pickle


def create_cnn():
  input_size=224
  #input_sizeは224,224までOK。

  vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(input_size,input_size, 3))
  last = vgg_conv.output

  vgg_conv.trainable = True

  set_trainable = False
  for layer in vgg_conv.layers:
    if layer.name == 'block5_conv1':
      set_trainable = True
    if set_trainable:
      layer.trainable = True
    else:
      layer.trainable = False

  mod = Flatten()(last)
  mod = Dense(256, activation='relu')(mod)
  #mod = Dropout(0.5)(mod)
  preds = Dense(10, activation='softmax')(mod)

  model = models.Model(vgg_conv.input, preds)

  return model

# %% [markdown]
# チェックポイントを定義(val lossが一番低い値の時にweightを保存)

# %%
class Checkpoint(Callback):
    def __init__(self, model, filepath):
        self.model = model
        self.filepath = filepath
        self.best_val_acc = 0.0
        self.best_val_loss = 0.1

    def on_epoch_end(self, epoch, logs):
        # val_accuracyが最大の時ににweightを保存する
        # if self.best_val_acc < logs["val_accuracy"]:
        #     self.model.save_weights(self.filepath)
        #     self.best_val_acc = logs["val_accuracy"]
        #     print("Weights saved.", self.best_val_acc)

        # val_lossが最小の時ににweightを保存する
        if self.best_val_loss > logs["val_loss"]:
            self.model.save_weights(self.filepath)
            self.best_val_loss = logs["val_loss"]
            print("Weights saved.", self.best_val_loss)
        # print(epoch + 1)

        # epochの最後にweightを保存する
        # if epoch == 99:
        #   print("epoch equals ", epoch)
        #   self.model.save_weights(self.filepath)
        #   self.best_val_loss = logs["val_loss"]
        #   print("Weights saved.", self.best_val_loss)

# %% [markdown]
# モデルを実行してアンサンブル学習させていきます

# %%
def train():
    print("train starts")
    hist = History()
    train_model = create_cnn()
    train_model.compile(optimizer=Adam(lr=1e-5),loss='categorical_crossentropy',metrics=['accuracy'])
    cp = Checkpoint(train_model, f"weights.hdf5")
    train_model.fit_generator(train_generator,epochs=100,validation_data=validation_generator,callbacks=[hist, cp])      

    return hist.history

# %%
K.clear_session()
hist = train()
# Out:
# train starts
# Epoch 1/100
# 90/90 [==============================] - 15s 172ms/step - loss: 2.0436 - accuracy: 0.2622 - val_loss: 1.8274 - val_accuracy: 0.3700
# Epoch 2/100
# 90/90 [==============================] - 14s 155ms/step - loss: 1.5432 - accuracy: 0.4378 - val_loss: 1.4980 - val_accuracy: 0.5489
# Epoch 3/100
# 90/90 [==============================] - 14s 156ms/step - loss: 1.2327 - accuracy: 0.5622 - val_loss: 0.4103 - val_accuracy: 0.6878
# Epoch 4/100
# 90/90 [==============================] - 14s 156ms/step - loss: 1.0157 - accuracy: 0.6289 - val_loss: 0.7252 - val_accuracy: 0.7156
# Epoch 5/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.8911 - accuracy: 0.6722 - val_loss: 0.5629 - val_accuracy: 0.7744
# Epoch 6/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.7845 - accuracy: 0.7200 - val_loss: 0.5233 - val_accuracy: 0.7722
# Epoch 7/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.7083 - accuracy: 0.7433 - val_loss: 0.2461 - val_accuracy: 0.8111
# Epoch 8/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.6446 - accuracy: 0.7689 - val_loss: 0.8069 - val_accuracy: 0.7989
# Epoch 9/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.5622 - accuracy: 0.8022 - val_loss: 0.5218 - val_accuracy: 0.8233
# Epoch 10/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.5311 - accuracy: 0.8278 - val_loss: 0.5221 - val_accuracy: 0.8156
# Epoch 11/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.4589 - accuracy: 0.8511 - val_loss: 0.2038 - val_accuracy: 0.8500
# Epoch 12/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.4571 - accuracy: 0.8333 - val_loss: 0.8303 - val_accuracy: 0.8456
# Epoch 13/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.4592 - accuracy: 0.8256 - val_loss: 0.5949 - val_accuracy: 0.8478
# Epoch 14/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.4152 - accuracy: 0.8556 - val_loss: 0.1678 - val_accuracy: 0.8411
# Epoch 15/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.3646 - accuracy: 0.8611 - val_loss: 0.3009 - val_accuracy: 0.8778
# Epoch 16/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.3721 - accuracy: 0.8778 - val_loss: 0.3119 - val_accuracy: 0.8389
# Epoch 17/100
# 90/90 [==============================] - 14s 154ms/step - loss: 0.3351 - accuracy: 0.8844 - val_loss: 0.2098 - val_accuracy: 0.8800
# Epoch 18/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.3367 - accuracy: 0.8822 - val_loss: 0.0316 - val_accuracy: 0.8833
# Weights saved. 0.03164675086736679
# Epoch 19/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.3142 - accuracy: 0.8889 - val_loss: 0.1334 - val_accuracy: 0.8511
# Epoch 20/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.3162 - accuracy: 0.8856 - val_loss: 0.1887 - val_accuracy: 0.8878
# Epoch 21/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.2754 - accuracy: 0.9189 - val_loss: 0.9924 - val_accuracy: 0.8856
# Epoch 22/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.2766 - accuracy: 0.9011 - val_loss: 0.4669 - val_accuracy: 0.9033
# Epoch 23/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.2597 - accuracy: 0.9122 - val_loss: 0.1706 - val_accuracy: 0.8911
# Epoch 24/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.2497 - accuracy: 0.9144 - val_loss: 0.7620 - val_accuracy: 0.8689
# Epoch 25/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.2296 - accuracy: 0.9244 - val_loss: 0.2085 - val_accuracy: 0.8800
# Epoch 26/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.2343 - accuracy: 0.9278 - val_loss: 0.1463 - val_accuracy: 0.9000
# Epoch 27/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.2514 - accuracy: 0.9089 - val_loss: 0.7866 - val_accuracy: 0.8978
# Epoch 28/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.2364 - accuracy: 0.9156 - val_loss: 0.5345 - val_accuracy: 0.8578
# Epoch 29/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.2269 - accuracy: 0.9200 - val_loss: 0.0216 - val_accuracy: 0.9044
# Weights saved. 0.021556565538048744
# Epoch 30/100
# 90/90 [==============================] - 14s 159ms/step - loss: 0.2225 - accuracy: 0.9211 - val_loss: 0.1128 - val_accuracy: 0.8889
# Epoch 31/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1844 - accuracy: 0.9344 - val_loss: 0.2199 - val_accuracy: 0.9044
# Epoch 32/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.2361 - accuracy: 0.9167 - val_loss: 0.3386 - val_accuracy: 0.8856
# Epoch 33/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1896 - accuracy: 0.9322 - val_loss: 0.8294 - val_accuracy: 0.9044
# Epoch 34/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1822 - accuracy: 0.9344 - val_loss: 0.1778 - val_accuracy: 0.9078
# Epoch 35/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1823 - accuracy: 0.9400 - val_loss: 0.2903 - val_accuracy: 0.9067
# Epoch 36/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1828 - accuracy: 0.9433 - val_loss: 0.3072 - val_accuracy: 0.9067
# Epoch 37/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1788 - accuracy: 0.9444 - val_loss: 0.2537 - val_accuracy: 0.9122
# Epoch 38/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1588 - accuracy: 0.9456 - val_loss: 0.4007 - val_accuracy: 0.9122
# Epoch 39/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1781 - accuracy: 0.9389 - val_loss: 0.0288 - val_accuracy: 0.8956
# Epoch 40/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1657 - accuracy: 0.9478 - val_loss: 0.0652 - val_accuracy: 0.9256
# Epoch 41/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1625 - accuracy: 0.9467 - val_loss: 0.7583 - val_accuracy: 0.9189
# Epoch 42/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1457 - accuracy: 0.9544 - val_loss: 1.2933 - val_accuracy: 0.9056
# Epoch 43/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1537 - accuracy: 0.9511 - val_loss: 0.2937 - val_accuracy: 0.8911
# Epoch 44/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1661 - accuracy: 0.9422 - val_loss: 0.3917 - val_accuracy: 0.9089
# Epoch 45/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1453 - accuracy: 0.9544 - val_loss: 0.0131 - val_accuracy: 0.8967
# Weights saved. 0.013099637813866138
# Epoch 46/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1354 - accuracy: 0.9500 - val_loss: 0.2110 - val_accuracy: 0.9022
# Epoch 47/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1663 - accuracy: 0.9400 - val_loss: 0.0555 - val_accuracy: 0.9056
# Epoch 48/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.1158 - accuracy: 0.9633 - val_loss: 0.0079 - val_accuracy: 0.9200
# Weights saved. 0.007938673719763756
# Epoch 49/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1246 - accuracy: 0.9544 - val_loss: 0.0053 - val_accuracy: 0.8922
# Weights saved. 0.005269221495836973
# Epoch 50/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1363 - accuracy: 0.9533 - val_loss: 0.1080 - val_accuracy: 0.9067
# Epoch 51/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1116 - accuracy: 0.9644 - val_loss: 0.1771 - val_accuracy: 0.8956
# Epoch 52/100
# 90/90 [==============================] - 14s 159ms/step - loss: 0.1418 - accuracy: 0.9533 - val_loss: 0.3597 - val_accuracy: 0.9244
# Epoch 53/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1160 - accuracy: 0.9644 - val_loss: 0.1160 - val_accuracy: 0.9167
# Epoch 54/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1058 - accuracy: 0.9678 - val_loss: 0.2590 - val_accuracy: 0.9011
# Epoch 55/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.1197 - accuracy: 0.9600 - val_loss: 0.3062 - val_accuracy: 0.8811
# Epoch 56/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1084 - accuracy: 0.9600 - val_loss: 0.4951 - val_accuracy: 0.9189
# Epoch 57/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.1029 - accuracy: 0.9667 - val_loss: 0.9444 - val_accuracy: 0.9100
# Epoch 58/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.1063 - accuracy: 0.9611 - val_loss: 0.0648 - val_accuracy: 0.9100
# Epoch 59/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0903 - accuracy: 0.9711 - val_loss: 0.0676 - val_accuracy: 0.9067
# Epoch 60/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1077 - accuracy: 0.9678 - val_loss: 0.1413 - val_accuracy: 0.8878
# Epoch 61/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0855 - accuracy: 0.9733 - val_loss: 0.3909 - val_accuracy: 0.9189
# Epoch 62/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1078 - accuracy: 0.9678 - val_loss: 0.0294 - val_accuracy: 0.9222
# Epoch 63/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.1068 - accuracy: 0.9611 - val_loss: 0.0064 - val_accuracy: 0.9089
# Epoch 64/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.0978 - accuracy: 0.9667 - val_loss: 0.3834 - val_accuracy: 0.8800
# Epoch 65/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0913 - accuracy: 0.9667 - val_loss: 0.0243 - val_accuracy: 0.9144
# Epoch 66/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.0868 - accuracy: 0.9778 - val_loss: 0.0022 - val_accuracy: 0.9156
# Weights saved. 0.002191476756706834
# Epoch 67/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0895 - accuracy: 0.9644 - val_loss: 0.0906 - val_accuracy: 0.8933
# Epoch 68/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0775 - accuracy: 0.9744 - val_loss: 0.0259 - val_accuracy: 0.9156
# Epoch 69/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0737 - accuracy: 0.9756 - val_loss: 0.2704 - val_accuracy: 0.9278
# Epoch 70/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0650 - accuracy: 0.9822 - val_loss: 0.2400 - val_accuracy: 0.9300
# Epoch 71/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.0789 - accuracy: 0.9733 - val_loss: 0.1198 - val_accuracy: 0.9033
# Epoch 72/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0782 - accuracy: 0.9767 - val_loss: 0.0056 - val_accuracy: 0.9111
# Epoch 73/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.1331 - accuracy: 0.9567 - val_loss: 0.0673 - val_accuracy: 0.9278
# Epoch 74/100
# 90/90 [==============================] - 14s 159ms/step - loss: 0.0957 - accuracy: 0.9678 - val_loss: 0.2646 - val_accuracy: 0.9078
# Epoch 75/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0821 - accuracy: 0.9756 - val_loss: 0.9566 - val_accuracy: 0.9178
# Epoch 76/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0651 - accuracy: 0.9778 - val_loss: 0.0088 - val_accuracy: 0.9144
# Epoch 77/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.0612 - accuracy: 0.9800 - val_loss: 0.2123 - val_accuracy: 0.9133
# Epoch 78/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0852 - accuracy: 0.9700 - val_loss: 0.5947 - val_accuracy: 0.9367
# Epoch 79/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0686 - accuracy: 0.9744 - val_loss: 0.1696 - val_accuracy: 0.9256
# Epoch 80/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0756 - accuracy: 0.9756 - val_loss: 0.0610 - val_accuracy: 0.9178
# Epoch 81/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.0789 - accuracy: 0.9733 - val_loss: 0.0283 - val_accuracy: 0.9122
# Epoch 82/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0713 - accuracy: 0.9767 - val_loss: 0.8811 - val_accuracy: 0.9144
# Epoch 83/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0966 - accuracy: 0.9689 - val_loss: 0.4777 - val_accuracy: 0.9011
# Epoch 84/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0644 - accuracy: 0.9822 - val_loss: 0.2633 - val_accuracy: 0.9344
# Epoch 85/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0712 - accuracy: 0.9778 - val_loss: 0.1816 - val_accuracy: 0.9189
# Epoch 86/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0659 - accuracy: 0.9778 - val_loss: 0.2907 - val_accuracy: 0.9133
# Epoch 87/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0475 - accuracy: 0.9889 - val_loss: 0.2928 - val_accuracy: 0.9278
# Epoch 88/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0722 - accuracy: 0.9744 - val_loss: 0.2004 - val_accuracy: 0.9278
# Epoch 89/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0520 - accuracy: 0.9811 - val_loss: 0.4698 - val_accuracy: 0.9100
# Epoch 90/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.0594 - accuracy: 0.9833 - val_loss: 0.2462 - val_accuracy: 0.9389
# Epoch 91/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0616 - accuracy: 0.9689 - val_loss: 0.6562 - val_accuracy: 0.8800
# Epoch 92/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0542 - accuracy: 0.9844 - val_loss: 0.1205 - val_accuracy: 0.9256
# Epoch 93/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0566 - accuracy: 0.9789 - val_loss: 0.1088 - val_accuracy: 0.9156
# Epoch 94/100
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0835 - accuracy: 0.9767 - val_loss: 0.0894 - val_accuracy: 0.9089
# Epoch 95/100
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0510 - accuracy: 0.9856 - val_loss: 0.0214 - val_accuracy: 0.9133
# Epoch 96/100
# 90/90 [==============================] - 14s 159ms/step - loss: 0.0665 - accuracy: 0.9800 - val_loss: 5.4613e-04 - val_accuracy: 0.9122
# Weights saved. 0.0005461328546516597
# Epoch 97/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.0593 - accuracy: 0.9789 - val_loss: 0.1048 - val_accuracy: 0.9122
# Epoch 98/100
# 90/90 [==============================] - 14s 158ms/step - loss: 0.0402 - accuracy: 0.9844 - val_loss: 0.0156 - val_accuracy: 0.9267
# Epoch 99/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.0568 - accuracy: 0.9867 - val_loss: 0.0485 - val_accuracy: 0.9233
# Epoch 100/100
# 90/90 [==============================] - 14s 155ms/step - loss: 0.0390 - accuracy: 0.9878 - val_loss: 1.5330 - val_accuracy: 0.9033

# %% [markdown]
# ■正解率と損失率をグラフ化

# %%
import matplotlib.pyplot as plt

history = hist

acc=history['accuracy']
val_acc=history['val_accuracy']
loss=history['loss']
val_loss=history['val_loss']

epochs=range(1,len(acc)+1)

#正解率plot
plt.plot(epochs,acc,'bo',label='Training acc')
plt.plot(epochs,val_acc,'b',label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()


#損失値をplot
plt.plot(epochs,loss,'bo',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ■学習した分類器を単体で検証

# %% [markdown]
# weightをロードして単体で検証します

# %%
def sin_predict():
  
    train_model = create_cnn()
    train_model.compile(optimizer=Adam(lr=1e-5),loss='categorical_crossentropy',metrics=['accuracy'])

    # 最良のモデルの読み込み
    train_model.load_weights(f"weights.hdf5")
    for layer in train_model.layers:
        layer.trainable = False

    # 単体の推論
    single_preds = np.argmax(train_model.predict_generator(prediction_generator), axis=-1)

    # 推論のスコア
    test_acc = accuracy_score(prediction_generator.classes[prediction_generator.index_array], single_preds)

    print("Test Accuracy : ", test_acc)

# %%
# 単体の推論
sin_predict()
# Out:
# Test Accuracy :  0.915
